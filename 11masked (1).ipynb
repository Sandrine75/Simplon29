# %%
# %matplotlib inline

# %% [markdown]
# Masked wordcloud
# ================
#
# Using a mask you can generate wordclouds in arbitrary shapes.

# %%
from os import path
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import os

from wordcloud import WordCloud, STOPWORDS

# get data directory (using getcwd() is needed to support running example in generated IPython notebook)
d = path.dirname(__file__) if "__file__" in locals() else os.getcwd()


# Read the whole text.
text = open(path.join(d, 'alice.txt')).read()
# IL VA CHERCHER LES DOSSIERS DANS JUPITER DONC CHARGER L4IMAGE ET LE TEXTE
  

# read the mask image
# taken from
# http://www.stencilry.org/stencils/movies/alice%20in%20wonderland/255fk.jpg
alice_mask = np.array(Image.open(path.join(d, "alice.png"))) # image d'entree  il y a deux images alice.png et alice_.png

stopwords = set(STOPWORDS)
stopwords.add("said")

wc = WordCloud(background_color="white", max_words=2000, mask=alice_mask,
               stopwords=stopwords, contour_width=3, contour_color='steelblue')

# generate word cloud
wc.generate(text)

# store to file
wc.to_file(path.join(d, "alice_.png")) # c'est l'image de sortie. Il faut donc l'appeler differemment >> alice_ car quand on appelle l'image puis on l'ecrase, cela va disparaitre...

# # show
plt.imshow(wc, interpolation='bilinear')  # affiche l image alice
plt.axis("off") # concerne la legende
#plt.figure() # affiche la legende ici caché
# plt.imshow(alice_mask, cmap=plt.cm.gray, interpolation='bilinear') >> affiche la deuxieme photo alice
# plt.axis("off")  cache l'apparition de l image en noir
plt.show()

# %%
from os import path
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import os

from wordcloud import WordCloud, STOPWORDS

# get data directory (using getcwd() is needed to support running example in generated IPython notebook)
d = path.dirname(__file__) if "__file__" in locals() else os.getcwd()


# Read the whole text.
text = open(path.join(d, 'bonne_annee_2020.txt')).read()
# IL VA CHERCHER LES DOSSIERS DANS JUPITER DONC CHARGER L4IMAGE ET LE TEXTE
  

# read the mask image
# taken from
# http://www.stencilry.org/stencils/movies/alice%20in%20wonderland/255fk.jpg
alice_mask = np.array(Image.open(path.join(d, "2020.png"))) # image d'entree  il y a deux images alice.png et alice_.png

stopwords = set(STOPWORDS)
stopwords.add("said")

wc = WordCloud(background_color="white", max_words=2000, mask=alice_mask,
               stopwords=stopwords, contour_width=3, contour_color='black')

# generate word cloud
wc.generate(text)

# store to file
wc.to_file(path.join(d, "2020_.png")) # c'est l'image de sortie. Il faut donc l'appeler differemment >> alice_ car quand on appelle l'image puis on l'ecrase, cela va disparaitre...

# # show
plt.imshow(wc, interpolation='bilinear')  # affiche l image alice
plt.axis("off") # concerne la legende
#plt.figure() # affiche la legende ici caché
# plt.imshow(alice_mask, cmap=plt.cm.gray, interpolation='bilinear') >> affiche la deuxieme photo alice
# plt.axis("off")  cache l'apparition de l image en noir
plt.show()

# %%
from os import path
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import os

from wordcloud import WordCloud, STOPWORDS

# get data directory (using getcwd() is needed to support running example in generated IPython notebook)
d = path.dirname(__file__) if "__file__" in locals() else os.getcwd()


# Read the whole text.
text = open(path.join(d, 'bonne_annee_2020.txt')).read()
# IL VA CHERCHER LES DOSSIERS DANS JUPITER DONC CHARGER L4IMAGE ET LE TEXTE
  

# read the mask image
# taken from
# http://www.stencilry.org/stencils/movies/alice%20in%20wonderland/255fk.jpg
alice_mask = np.array(Image.open(path.join(d, "YACINE.png"))) # image d'entree  il y a deux images alice.png et alice_.png

stopwords = set(STOPWORDS)
stopwords.add("said")

wc = WordCloud(background_color="white", max_words=2000, mask=alice_mask,
               stopwords=stopwords, contour_width=3, contour_color='black')

# generate word cloud
wc.generate(text)

# store to file
wc.to_file(path.join(d, "YACINE_.png")) # c'est l'image de sortie. Il faut donc l'appeler differemment >> alice_ car quand on appelle l'image puis on l'ecrase, cela va disparaitre...

# # show
plt.imshow(wc, interpolation='bilinear')  # affiche l image alice
plt.axis("off") # concerne la legende
#plt.figure() # affiche la legende ici caché
# plt.imshow(alice_mask, cmap=plt.cm.gray, interpolation='bilinear') >> affiche la deuxieme photo alice
# plt.axis("off")  cache l'apparition de l image en noir
plt.show()
